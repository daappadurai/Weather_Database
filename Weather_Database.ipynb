# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90,90,2000)
lngs = np.random.uniform(-180,180,2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
coordinates= zip(lats,lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
# YOUR CODE HERE

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
len(cities)
# Print the city count to confirm sufficient count
# YOUR CODE HERE
# Out:
# 772

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import API_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + API_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"] 
        city_weather_description = city_weather["weather"][0]["description"]     
            
        # Append the city information into the city_data list
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Weather": city_weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | tabou
# Processing Record 3 of Set 1 | luau
# Processing Record 4 of Set 1 | turangi
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | tuktoyaktuk
# Processing Record 7 of Set 1 | yellowknife
# Processing Record 8 of Set 1 | upernavik
# Processing Record 9 of Set 1 | bethel
# Processing Record 10 of Set 1 | belomorsk
# Processing Record 11 of Set 1 | gimli
# Processing Record 12 of Set 1 | dingle
# Processing Record 13 of Set 1 | huarmey
# Processing Record 14 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 1 | vila do maio
# Processing Record 16 of Set 1 | cape town
# Processing Record 17 of Set 1 | katsuura
# Processing Record 18 of Set 1 | ancud
# Processing Record 19 of Set 1 | ostrovnoy
# Processing Record 20 of Set 1 | saint-philippe
# Processing Record 21 of Set 1 | san quintin
# Processing Record 22 of Set 1 | geraldton
# Processing Record 23 of Set 1 | baltasi
# Processing Record 24 of Set 1 | freeport
# Processing Record 25 of Set 1 | bilma
# Processing Record 26 of Set 1 | roald
# Processing Record 27 of Set 1 | atuona
# Processing Record 28 of Set 1 | lompoc
# Processing Record 29 of Set 1 | bardiyah
# Processing Record 30 of Set 1 | touros
# Processing Record 31 of Set 1 | sinkat
# City not found. Skipping...
# Processing Record 32 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 1 | leningradskiy
# Processing Record 34 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 1 | namibe
# Processing Record 36 of Set 1 | razole
# Processing Record 37 of Set 1 | punta arenas
# Processing Record 38 of Set 1 | belmonte
# Processing Record 39 of Set 1 | ifanadiana
# Processing Record 40 of Set 1 | lebu
# Processing Record 41 of Set 1 | skalistyy
# City not found. Skipping...
# Processing Record 42 of Set 1 | rikitea
# Processing Record 43 of Set 1 | hermanus
# Processing Record 44 of Set 1 | nikolskoye
# Processing Record 45 of Set 1 | liberty
# Processing Record 46 of Set 1 | sandwick
# Processing Record 47 of Set 1 | kapaa
# Processing Record 48 of Set 1 | linjiang
# Processing Record 49 of Set 1 | castro
# Processing Record 50 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 1 of Set 2 | norman wells
# Processing Record 2 of Set 2 | qaanaaq
# Processing Record 3 of Set 2 | hilo
# Processing Record 4 of Set 2 | nome
# Processing Record 5 of Set 2 | mataura
# Processing Record 6 of Set 2 | butaritari
# Processing Record 7 of Set 2 | novobirilyussy
# Processing Record 8 of Set 2 | bokspits
# City not found. Skipping...
# Processing Record 9 of Set 2 | avarua
# Processing Record 10 of Set 2 | bredasdorp
# Processing Record 11 of Set 2 | pousat
# City not found. Skipping...
# Processing Record 12 of Set 2 | north battleford
# Processing Record 13 of Set 2 | ellisras
# Processing Record 14 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 2 | bluff
# Processing Record 16 of Set 2 | aksu
# Processing Record 17 of Set 2 | aripuana
# Processing Record 18 of Set 2 | tasiilaq
# Processing Record 19 of Set 2 | vila velha
# Processing Record 20 of Set 2 | narsaq
# Processing Record 21 of Set 2 | berdigestyakh
# Processing Record 22 of Set 2 | jamestown
# Processing Record 23 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 2 | voyinka
# Processing Record 25 of Set 2 | auki
# Processing Record 26 of Set 2 | gualaquiza
# Processing Record 27 of Set 2 | champerico
# Processing Record 28 of Set 2 | mahebourg
# Processing Record 29 of Set 2 | yulara
# Processing Record 30 of Set 2 | grand forks
# Processing Record 31 of Set 2 | erenhot
# Processing Record 32 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 2 | east london
# Processing Record 34 of Set 2 | busselton
# Processing Record 35 of Set 2 | port blair
# Processing Record 36 of Set 2 | kiunga
# Processing Record 37 of Set 2 | saskylakh
# Processing Record 38 of Set 2 | new norfolk
# Processing Record 39 of Set 2 | jadu
# Processing Record 40 of Set 2 | camana
# Processing Record 41 of Set 2 | albany
# Processing Record 42 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 43 of Set 2 | verona
# Processing Record 44 of Set 2 | nouakchott
# Processing Record 45 of Set 2 | saint-francois
# Processing Record 46 of Set 2 | hervey bay
# Processing Record 47 of Set 2 | martapura
# Processing Record 48 of Set 2 | sakakah
# Processing Record 49 of Set 2 | clyde river
# Processing Record 50 of Set 2 | san cristobal
# Processing Record 1 of Set 3 | wuda
# Processing Record 2 of Set 3 | tarko-sale
# Processing Record 3 of Set 3 | nanortalik
# Processing Record 4 of Set 3 | polewali
# Processing Record 5 of Set 3 | bundaberg
# Processing Record 6 of Set 3 | margherita
# Processing Record 7 of Set 3 | young
# Processing Record 8 of Set 3 | port alfred
# Processing Record 9 of Set 3 | mount gambier
# Processing Record 10 of Set 3 | ribeira grande
# Processing Record 11 of Set 3 | itacurubi del rosario
# Processing Record 12 of Set 3 | ilyich
# Processing Record 13 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 3 | mutis
# Processing Record 15 of Set 3 | alofi
# Processing Record 16 of Set 3 | badarganj
# Processing Record 17 of Set 3 | sanandaj
# Processing Record 18 of Set 3 | barra do corda
# Processing Record 19 of Set 3 | nyurba
# Processing Record 20 of Set 3 | lavrentiya
# Processing Record 21 of Set 3 | samarai
# Processing Record 22 of Set 3 | quatre cocos
# Processing Record 23 of Set 3 | palmer
# Processing Record 24 of Set 3 | port hedland
# Processing Record 25 of Set 3 | tuatapere
# Processing Record 26 of Set 3 | hobart
# Processing Record 27 of Set 3 | zhigansk
# Processing Record 28 of Set 3 | twin falls
# Processing Record 29 of Set 3 | ingham
# Processing Record 30 of Set 3 | kenai
# Processing Record 31 of Set 3 | kavaratti
# Processing Record 32 of Set 3 | nkongsamba
# Processing Record 33 of Set 3 | airai
# Processing Record 34 of Set 3 | nuristan
# Processing Record 35 of Set 3 | ust-maya
# Processing Record 36 of Set 3 | hualmay
# Processing Record 37 of Set 3 | longyearbyen
# Processing Record 38 of Set 3 | bangkalan
# Processing Record 39 of Set 3 | iqaluit
# Processing Record 40 of Set 3 | lodwar
# Processing Record 41 of Set 3 | ulundi
# Processing Record 42 of Set 3 | nemuro
# Processing Record 43 of Set 3 | esperance
# Processing Record 44 of Set 3 | ilabaya
# Processing Record 45 of Set 3 | tornio
# Processing Record 46 of Set 3 | provideniya
# Processing Record 47 of Set 3 | bengkulu
# Processing Record 48 of Set 3 | chenghai
# Processing Record 49 of Set 3 | golden
# Processing Record 50 of Set 3 | kaitangata
# Processing Record 1 of Set 4 | berlevag
# Processing Record 2 of Set 4 | torbay
# Processing Record 3 of Set 4 | diffa
# Processing Record 4 of Set 4 | puerto ayora
# Processing Record 5 of Set 4 | hithadhoo
# Processing Record 6 of Set 4 | kodiak
# Processing Record 7 of Set 4 | santa isabel do rio negro
# Processing Record 8 of Set 4 | sandwich
# Processing Record 9 of Set 4 | keskin
# Processing Record 10 of Set 4 | romitan
# Processing Record 11 of Set 4 | liepaja
# Processing Record 12 of Set 4 | salta
# Processing Record 13 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 14 of Set 4 | namatanai
# Processing Record 15 of Set 4 | cidreira
# Processing Record 16 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 4 | grindavik
# Processing Record 18 of Set 4 | rio gallegos
# Processing Record 19 of Set 4 | san policarpo
# Processing Record 20 of Set 4 | angoche
# Processing Record 21 of Set 4 | georgetown
# Processing Record 22 of Set 4 | comodoro rivadavia
# Processing Record 23 of Set 4 | iquique
# Processing Record 24 of Set 4 | alice springs
# Processing Record 25 of Set 4 | trinidad
# Processing Record 26 of Set 4 | cayenne
# Processing Record 27 of Set 4 | port hardy
# Processing Record 28 of Set 4 | baykit
# Processing Record 29 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 4 | tateyama
# Processing Record 31 of Set 4 | eirunepe
# Processing Record 32 of Set 4 | akureyri
# Processing Record 33 of Set 4 | lorengau
# Processing Record 34 of Set 4 | arraial do cabo
# Processing Record 35 of Set 4 | burnie
# Processing Record 36 of Set 4 | sao miguel do araguaia
# Processing Record 37 of Set 4 | hobyo
# Processing Record 38 of Set 4 | sao filipe
# Processing Record 39 of Set 4 | terre haute
# Processing Record 40 of Set 4 | kruisfontein
# Processing Record 41 of Set 4 | yabrud
# Processing Record 42 of Set 4 | yelizovo
# Processing Record 43 of Set 4 | marrakesh
# Processing Record 44 of Set 4 | arrifes
# Processing Record 45 of Set 4 | chuy
# Processing Record 46 of Set 4 | tiksi
# Processing Record 47 of Set 4 | salalah
# Processing Record 48 of Set 4 | lukulu
# Processing Record 49 of Set 4 | mao
# Processing Record 50 of Set 4 | vestmannaeyjar
# Processing Record 1 of Set 5 | magistralnyy
# Processing Record 2 of Set 5 | svinita
# Processing Record 3 of Set 5 | barrow
# Processing Record 4 of Set 5 | manoel urbano
# Processing Record 5 of Set 5 | port elizabeth
# Processing Record 6 of Set 5 | porto novo
# Processing Record 7 of Set 5 | sitka
# Processing Record 8 of Set 5 | maiquetia
# Processing Record 9 of Set 5 | abalak
# Processing Record 10 of Set 5 | nisia floresta
# Processing Record 11 of Set 5 | pangnirtung
# Processing Record 12 of Set 5 | huhi
# Processing Record 13 of Set 5 | chokurdakh
# Processing Record 14 of Set 5 | muros
# Processing Record 15 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 5 | fairbanks
# Processing Record 17 of Set 5 | pilna
# Processing Record 18 of Set 5 | bambous virieux
# Processing Record 19 of Set 5 | victoria
# Processing Record 20 of Set 5 | khor
# Processing Record 21 of Set 5 | yaan
# Processing Record 22 of Set 5 | kupang
# Processing Record 23 of Set 5 | doha
# Processing Record 24 of Set 5 | broome
# Processing Record 25 of Set 5 | rolim de moura
# City not found. Skipping...
# Processing Record 26 of Set 5 | buala
# Processing Record 27 of Set 5 | port hueneme
# Processing Record 28 of Set 5 | egvekinot
# Processing Record 29 of Set 5 | kavieng
# Processing Record 30 of Set 5 | ushtobe
# Processing Record 31 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 5 | khomutovka
# Processing Record 33 of Set 5 | pasighat
# Processing Record 34 of Set 5 | dhanwar
# Processing Record 35 of Set 5 | bom jesus da lapa
# Processing Record 36 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 37 of Set 5 | grand gaube
# Processing Record 38 of Set 5 | tecolutilla
# Processing Record 39 of Set 5 | ust-ordynskiy
# Processing Record 40 of Set 5 | ambilobe
# Processing Record 41 of Set 5 | carnarvon
# Processing Record 42 of Set 5 | puerto maldonado
# Processing Record 43 of Set 5 | alugan
# Processing Record 44 of Set 5 | dikson
# Processing Record 45 of Set 5 | klaksvik
# Processing Record 46 of Set 5 | udachnyy
# Processing Record 47 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 5 | cabo san lucas
# Processing Record 49 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 50 of Set 5 | matara
# Processing Record 1 of Set 6 | siniscola
# Processing Record 2 of Set 6 | kutum
# Processing Record 3 of Set 6 | olafsvik
# Processing Record 4 of Set 6 | ponta delgada
# Processing Record 5 of Set 6 | hambantota
# Processing Record 6 of Set 6 | ilulissat
# Processing Record 7 of Set 6 | padilla
# Processing Record 8 of Set 6 | mar del plata
# Processing Record 9 of Set 6 | brae
# Processing Record 10 of Set 6 | constitucion
# Processing Record 11 of Set 6 | lang son
# Processing Record 12 of Set 6 | ust-kuyga
# Processing Record 13 of Set 6 | lima
# Processing Record 14 of Set 6 | starogard gdanski
# Processing Record 15 of Set 6 | kilosa
# Processing Record 16 of Set 6 | artyk
# City not found. Skipping...
# Processing Record 17 of Set 6 | lasa
# Processing Record 18 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 6 | vysha
# Processing Record 20 of Set 6 | karbinci
# Processing Record 21 of Set 6 | ithaca
# Processing Record 22 of Set 6 | saint-joseph
# Processing Record 23 of Set 6 | makakilo city
# Processing Record 24 of Set 6 | playa vicente
# Processing Record 25 of Set 6 | gazli
# Processing Record 26 of Set 6 | hamilton
# Processing Record 27 of Set 6 | mayo
# Processing Record 28 of Set 6 | adeje
# Processing Record 29 of Set 6 | sobolevo
# Processing Record 30 of Set 6 | witrivier
# City not found. Skipping...
# Processing Record 31 of Set 6 | mehamn
# Processing Record 32 of Set 6 | navolato
# Processing Record 33 of Set 6 | kocevje
# Processing Record 34 of Set 6 | kazanka
# Processing Record 35 of Set 6 | axim
# Processing Record 36 of Set 6 | sola
# Processing Record 37 of Set 6 | hasaki
# Processing Record 38 of Set 6 | vilyuysk
# Processing Record 39 of Set 6 | paracatu
# Processing Record 40 of Set 6 | fortuna
# Processing Record 41 of Set 6 | dhupgari
# Processing Record 42 of Set 6 | takoradi
# Processing Record 43 of Set 6 | sechura
# Processing Record 44 of Set 6 | novikovo
# Processing Record 45 of Set 6 | tura
# Processing Record 46 of Set 6 | krasnoselkup
# Processing Record 47 of Set 6 | bocas del toro
# Processing Record 48 of Set 6 | taltal
# Processing Record 49 of Set 6 | pevek
# Processing Record 50 of Set 6 | pozo colorado
# Processing Record 1 of Set 7 | umm ruwabah
# City not found. Skipping...
# Processing Record 2 of Set 7 | camacha
# Processing Record 3 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 4 of Set 7 | cedar city
# Processing Record 5 of Set 7 | ponta do sol
# Processing Record 6 of Set 7 | kaili
# Processing Record 7 of Set 7 | taoudenni
# Processing Record 8 of Set 7 | sioux lookout
# Processing Record 9 of Set 7 | bilibino
# Processing Record 10 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 11 of Set 7 | mareeba
# Processing Record 12 of Set 7 | maputo
# Processing Record 13 of Set 7 | khani
# Processing Record 14 of Set 7 | richards bay
# Processing Record 15 of Set 7 | saint george
# Processing Record 16 of Set 7 | aksarka
# Processing Record 17 of Set 7 | vad
# Processing Record 18 of Set 7 | terrak
# Processing Record 19 of Set 7 | sao joao da barra
# Processing Record 20 of Set 7 | ossora
# Processing Record 21 of Set 7 | cockburn town
# Processing Record 22 of Set 7 | lianzhou
# Processing Record 23 of Set 7 | poum
# Processing Record 24 of Set 7 | cherskiy
# Processing Record 25 of Set 7 | creston
# Processing Record 26 of Set 7 | hofn
# Processing Record 27 of Set 7 | pochutla
# Processing Record 28 of Set 7 | nhulunbuy
# Processing Record 29 of Set 7 | ji-parana
# City not found. Skipping...
# Processing Record 30 of Set 7 | pisco
# Processing Record 31 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 32 of Set 7 | martinsicuro
# Processing Record 33 of Set 7 | ouadda
# Processing Record 34 of Set 7 | baiyin
# Processing Record 35 of Set 7 | fort nelson
# Processing Record 36 of Set 7 | santa fe
# Processing Record 37 of Set 7 | tartagal
# Processing Record 38 of Set 7 | cururupu
# Processing Record 39 of Set 7 | karasjok
# Processing Record 40 of Set 7 | inuvik
# Processing Record 41 of Set 7 | san patricio
# Processing Record 42 of Set 7 | sinnamary
# Processing Record 43 of Set 7 | san pedro
# Processing Record 44 of Set 7 | katherine
# Processing Record 45 of Set 7 | thompson
# Processing Record 46 of Set 7 | manokwari
# Processing Record 47 of Set 7 | talas
# Processing Record 48 of Set 7 | nouadhibou
# Processing Record 49 of Set 7 | shingu
# Processing Record 50 of Set 7 | awbari
# Processing Record 1 of Set 8 | vanimo
# Processing Record 2 of Set 8 | poltavka
# Processing Record 3 of Set 8 | belyy yar
# Processing Record 4 of Set 8 | cap malheureux
# Processing Record 5 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 8 | khatanga
# Processing Record 7 of Set 8 | vestmanna
# Processing Record 8 of Set 8 | shirokiy
# Processing Record 9 of Set 8 | najran
# Processing Record 10 of Set 8 | la ronge
# Processing Record 11 of Set 8 | dudinka
# Processing Record 12 of Set 8 | galgani
# City not found. Skipping...
# Processing Record 13 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 8 | saldanha
# Processing Record 15 of Set 8 | harsin
# Processing Record 16 of Set 8 | daru
# Processing Record 17 of Set 8 | launceston
# Processing Record 18 of Set 8 | ketchikan
# Processing Record 19 of Set 8 | wilmington
# Processing Record 20 of Set 8 | nuuk
# Processing Record 21 of Set 8 | gejiu
# Processing Record 22 of Set 8 | shenjiamen
# Processing Record 23 of Set 8 | mantua
# Processing Record 24 of Set 8 | ambovombe
# Processing Record 25 of Set 8 | ituni
# City not found. Skipping...
# Processing Record 26 of Set 8 | acqui terme
# Processing Record 27 of Set 8 | llangefni
# Processing Record 28 of Set 8 | tukrah
# Processing Record 29 of Set 8 | taga
# Processing Record 30 of Set 8 | half moon bay
# Processing Record 31 of Set 8 | ajdabiya
# Processing Record 32 of Set 8 | churapcha
# Processing Record 33 of Set 8 | taburi
# City not found. Skipping...
# Processing Record 34 of Set 8 | toora-khem
# Processing Record 35 of Set 8 | lagoa
# Processing Record 36 of Set 8 | rochegda
# Processing Record 37 of Set 8 | ahipara
# Processing Record 38 of Set 8 | boa vista
# Processing Record 39 of Set 8 | yendi
# Processing Record 40 of Set 8 | vardo
# Processing Record 41 of Set 8 | vega de alatorre
# Processing Record 42 of Set 8 | korla
# Processing Record 43 of Set 8 | krasnyy chikoy
# Processing Record 44 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 45 of Set 8 | omaruru
# Processing Record 46 of Set 8 | tautira
# Processing Record 47 of Set 8 | qiryat shemona
# Processing Record 48 of Set 8 | conil
# Processing Record 49 of Set 8 | guicheng
# City not found. Skipping...
# Processing Record 50 of Set 8 | tarauaca
# Processing Record 1 of Set 9 | puerto escondido
# Processing Record 2 of Set 9 | chumikan
# Processing Record 3 of Set 9 | deputatskiy
# Processing Record 4 of Set 9 | karonga
# Processing Record 5 of Set 9 | nadym
# Processing Record 6 of Set 9 | bandraboua
# Processing Record 7 of Set 9 | puerto colombia
# Processing Record 8 of Set 9 | binga
# Processing Record 9 of Set 9 | saint anthony
# Processing Record 10 of Set 9 | pershotravneve
# Processing Record 11 of Set 9 | biankouma
# Processing Record 12 of Set 9 | severo-kurilsk
# Processing Record 13 of Set 9 | port macquarie
# Processing Record 14 of Set 9 | kijang
# Processing Record 15 of Set 9 | partizanskoye
# Processing Record 16 of Set 9 | skagastrond
# City not found. Skipping...
# Processing Record 17 of Set 9 | gilbues
# Processing Record 18 of Set 9 | carutapera
# Processing Record 19 of Set 9 | souillac
# Processing Record 20 of Set 9 | adamovka
# Processing Record 21 of Set 9 | touba
# Processing Record 22 of Set 9 | codrington
# Processing Record 23 of Set 9 | bathsheba
# Processing Record 24 of Set 9 | bowen
# Processing Record 25 of Set 9 | guanica
# Processing Record 26 of Set 9 | bandarbeyla
# Processing Record 27 of Set 9 | mustasaari
# Processing Record 28 of Set 9 | bubaque
# Processing Record 29 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 30 of Set 9 | chau doc
# Processing Record 31 of Set 9 | stephenville
# Processing Record 32 of Set 9 | atar
# Processing Record 33 of Set 9 | lysva
# Processing Record 34 of Set 9 | san antonio
# Processing Record 35 of Set 9 | varkkallai
# Processing Record 36 of Set 9 | sayyan
# Processing Record 37 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 9 | calamar
# Processing Record 39 of Set 9 | tutoia
# Processing Record 40 of Set 9 | zeya
# Processing Record 41 of Set 9 | jvari
# Processing Record 42 of Set 9 | bonthe
# Processing Record 43 of Set 9 | moscow
# Processing Record 44 of Set 9 | salamiyah
# Processing Record 45 of Set 9 | port-cartier
# Processing Record 46 of Set 9 | ayna
# Processing Record 47 of Set 9 | bangassou
# Processing Record 48 of Set 9 | balabac
# Processing Record 49 of Set 9 | klyuchi
# Processing Record 50 of Set 9 | talnakh
# Processing Record 1 of Set 10 | hilton head island
# Processing Record 2 of Set 10 | ejura
# Processing Record 3 of Set 10 | date
# Processing Record 4 of Set 10 | dinsor
# City not found. Skipping...
# Processing Record 5 of Set 10 | guerrero negro
# Processing Record 6 of Set 10 | kuah
# Processing Record 7 of Set 10 | logrono
# Processing Record 8 of Set 10 | wau
# Processing Record 9 of Set 10 | anadyr
# Processing Record 10 of Set 10 | sao joao del rei
# Processing Record 11 of Set 10 | san vicente
# Processing Record 12 of Set 10 | alekseyevka
# Processing Record 13 of Set 10 | marzuq
# Processing Record 14 of Set 10 | broken hill
# Processing Record 15 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 16 of Set 10 | natal
# Processing Record 17 of Set 10 | akkudah
# City not found. Skipping...
# Processing Record 18 of Set 10 | agadez
# Processing Record 19 of Set 10 | sisimiut
# Processing Record 20 of Set 10 | owando
# Processing Record 21 of Set 10 | urusha
# Processing Record 22 of Set 10 | craig
# Processing Record 23 of Set 10 | albury
# Processing Record 24 of Set 10 | khingansk
# Processing Record 25 of Set 10 | beringovskiy
# Processing Record 26 of Set 10 | nsoko
# Processing Record 27 of Set 10 | okha
# Processing Record 28 of Set 10 | goya
# Processing Record 29 of Set 10 | ksenyevka
# City not found. Skipping...
# Processing Record 30 of Set 10 | goba
# Processing Record 31 of Set 10 | cabra
# Processing Record 32 of Set 10 | uruzgan
# Processing Record 33 of Set 10 | bahia blanca
# Processing Record 34 of Set 10 | antofagasta
# Processing Record 35 of Set 10 | jining
# Processing Record 36 of Set 10 | ahumada
# City not found. Skipping...
# Processing Record 37 of Set 10 | sunrise manor
# Processing Record 38 of Set 10 | peleduy
# Processing Record 39 of Set 10 | le portel
# Processing Record 40 of Set 10 | uige
# Processing Record 41 of Set 10 | semey
# Processing Record 42 of Set 10 | livingston
# Processing Record 43 of Set 10 | lata
# Processing Record 44 of Set 10 | meulaboh
# Processing Record 45 of Set 10 | gorodovikovsk
# Processing Record 46 of Set 10 | wellington
# Processing Record 47 of Set 10 | kostomuksha
# Processing Record 48 of Set 10 | kuleshovka
# Processing Record 49 of Set 10 | parma
# Processing Record 50 of Set 10 | isiro
# Processing Record 1 of Set 11 | xinzhi
# Processing Record 2 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 11 | zyrardow
# Processing Record 4 of Set 11 | palauig
# Processing Record 5 of Set 11 | nishihara
# Processing Record 6 of Set 11 | mazagao
# Processing Record 7 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 8 of Set 11 | port said
# Processing Record 9 of Set 11 | puerto madryn
# Processing Record 10 of Set 11 | paso de carrasco
# Processing Record 11 of Set 11 | adrar
# Processing Record 12 of Set 11 | pacific grove
# Processing Record 13 of Set 11 | viedma
# Processing Record 14 of Set 11 | yining
# Processing Record 15 of Set 11 | berezivka
# Processing Record 16 of Set 11 | bairiki
# Processing Record 17 of Set 11 | sheltozero
# Processing Record 18 of Set 11 | bumbuna
# Processing Record 19 of Set 11 | kosovo polje
# Processing Record 20 of Set 11 | erzin
# Processing Record 21 of Set 11 | celestun
# Processing Record 22 of Set 11 | benjamin aceval
# Processing Record 23 of Set 11 | kota tinggi
# Processing Record 24 of Set 11 | voh
# Processing Record 25 of Set 11 | itamarandiba
# Processing Record 26 of Set 11 | ukiah
# Processing Record 27 of Set 11 | kattivakkam
# Processing Record 28 of Set 11 | teknaf
# Processing Record 29 of Set 11 | caravelas
# Processing Record 30 of Set 11 | mount isa
# Processing Record 31 of Set 11 | zyryanka
# Processing Record 32 of Set 11 | sidi ali
# Processing Record 33 of Set 11 | teguise
# Processing Record 34 of Set 11 | tonantins
# Processing Record 35 of Set 11 | abu samrah
# Processing Record 36 of Set 11 | knoxville
# Processing Record 37 of Set 11 | college
# Processing Record 38 of Set 11 | sibolga
# Processing Record 39 of Set 11 | loandjili
# Processing Record 40 of Set 11 | katobu
# Processing Record 41 of Set 11 | asfi
# Processing Record 42 of Set 11 | zaranj
# Processing Record 43 of Set 11 | pangkalanbuun
# Processing Record 44 of Set 11 | kayerkan
# Processing Record 45 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 11 | shizilu
# Processing Record 47 of Set 11 | manuk mangkaw
# Processing Record 48 of Set 11 | walvis bay
# Processing Record 49 of Set 11 | bouca
# Processing Record 50 of Set 11 | kigali
# Processing Record 1 of Set 12 | petrovsk
# Processing Record 2 of Set 12 | vila franca do campo
# Processing Record 3 of Set 12 | solnechnyy
# Processing Record 4 of Set 12 | vryheid
# Processing Record 5 of Set 12 | killybegs
# Processing Record 6 of Set 12 | esso
# Processing Record 7 of Set 12 | gao
# Processing Record 8 of Set 12 | kaifeng
# Processing Record 9 of Set 12 | topliceni
# Processing Record 10 of Set 12 | souris
# Processing Record 11 of Set 12 | kalabo
# Processing Record 12 of Set 12 | blackwater
# Processing Record 13 of Set 12 | port lincoln
# Processing Record 14 of Set 12 | avera
# Processing Record 15 of Set 12 | kahta
# Processing Record 16 of Set 12 | gamba
# Processing Record 17 of Set 12 | grafton
# Processing Record 18 of Set 12 | salinas
# Processing Record 19 of Set 12 | singaparna
# Processing Record 20 of Set 12 | manutuke
# Processing Record 21 of Set 12 | rapid valley
# Processing Record 22 of Set 12 | fort stewart
# Processing Record 23 of Set 12 | esil
# Processing Record 24 of Set 12 | mitu
# Processing Record 25 of Set 12 | nakano
# Processing Record 26 of Set 12 | bereda
# Processing Record 27 of Set 12 | juegang
# Processing Record 28 of Set 12 | cape elizabeth
# City not found. Skipping...
# Processing Record 29 of Set 12 | zhezkazgan
# Processing Record 30 of Set 12 | oranjemund
# Processing Record 31 of Set 12 | zamania
# Processing Record 32 of Set 12 | katangli
# Processing Record 33 of Set 12 | kisangani
# Processing Record 34 of Set 12 | teya
# Processing Record 35 of Set 12 | barra patuca
# Processing Record 36 of Set 12 | morgan city
# Processing Record 37 of Set 12 | warud
# Processing Record 38 of Set 12 | evensk
# Processing Record 39 of Set 12 | am timan
# Processing Record 40 of Set 12 | semnan
# Processing Record 41 of Set 12 | jalu
# Processing Record 42 of Set 12 | vargashi
# Processing Record 43 of Set 12 | wazzan
# City not found. Skipping...
# Processing Record 44 of Set 12 | rehoboth
# Processing Record 45 of Set 12 | tsiroanomandidy
# Processing Record 46 of Set 12 | westport
# Processing Record 47 of Set 12 | roma
# Processing Record 48 of Set 12 | safford
# Processing Record 49 of Set 12 | rawson
# Processing Record 50 of Set 12 | kemi
# Processing Record 1 of Set 13 | marienburg
# Processing Record 2 of Set 13 | moree
# Processing Record 3 of Set 13 | palm coast
# Processing Record 4 of Set 13 | ambon
# Processing Record 5 of Set 13 | banda aceh
# Processing Record 6 of Set 13 | marovoay
# Processing Record 7 of Set 13 | dalen
# Processing Record 8 of Set 13 | achutupo
# Processing Record 9 of Set 13 | kloulklubed
# Processing Record 10 of Set 13 | road town
# Processing Record 11 of Set 13 | le port
# Processing Record 12 of Set 13 | luderitz
# Processing Record 13 of Set 13 | maldonado
# Processing Record 14 of Set 13 | oriximina
# Processing Record 15 of Set 13 | the valley
# Processing Record 16 of Set 13 | douglas
# Processing Record 17 of Set 13 | ambikapur
# Processing Record 18 of Set 13 | naze
# Processing Record 19 of Set 13 | wanning
# Processing Record 20 of Set 13 | saquena
# Processing Record 21 of Set 13 | letka
# Processing Record 22 of Set 13 | sudogda
# Processing Record 23 of Set 13 | belaya gora
# Processing Record 24 of Set 13 | harbour breton
# Processing Record 25 of Set 13 | agucadoura
# Processing Record 26 of Set 13 | tulun
# Processing Record 27 of Set 13 | phan rang
# City not found. Skipping...
# Processing Record 28 of Set 13 | akyab
# Processing Record 29 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 13 | kologriv
# Processing Record 31 of Set 13 | kostino
# Processing Record 32 of Set 13 | riyadh
# Processing Record 33 of Set 13 | srednekolymsk
# Processing Record 34 of Set 13 | shimanovsk
# Processing Record 35 of Set 13 | moerai
# Processing Record 36 of Set 13 | skeldon
# Processing Record 37 of Set 13 | itoman
# Processing Record 38 of Set 13 | amapa
# Processing Record 39 of Set 13 | sendhwa
# Processing Record 40 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 41 of Set 13 | tromso
# Processing Record 42 of Set 13 | kahului
# Processing Record 43 of Set 13 | neiafu
# Processing Record 44 of Set 13 | maroantsetra
# Processing Record 45 of Set 13 | kamaishi
# Processing Record 46 of Set 13 | mishan
# Processing Record 47 of Set 13 | abha
# Processing Record 48 of Set 13 | slave lake
# Processing Record 49 of Set 13 | ikryanoye
# Processing Record 50 of Set 13 | los llanos de aridane
# Processing Record 1 of Set 14 | hami
# Processing Record 2 of Set 14 | mitsamiouli
# Processing Record 3 of Set 14 | bam
# Processing Record 4 of Set 14 | christchurch
# Processing Record 5 of Set 14 | balkanabat
# Processing Record 6 of Set 14 | mahajanga
# Processing Record 7 of Set 14 | hurricane
# Processing Record 8 of Set 14 | isangel
# Processing Record 9 of Set 14 | shitkino
# Processing Record 10 of Set 14 | turbat
# Processing Record 11 of Set 14 | almeirim
# Processing Record 12 of Set 14 | kulhudhuffushi
# Processing Record 13 of Set 14 | vanavara
# Processing Record 14 of Set 14 | shimabara
# Processing Record 15 of Set 14 | saint-augustin
# Processing Record 16 of Set 14 | jinji
# Processing Record 17 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 18 of Set 14 | balkhash
# Processing Record 19 of Set 14 | necochea
# Processing Record 20 of Set 14 | aksha
# Processing Record 21 of Set 14 | nador
# Processing Record 22 of Set 14 | eureka
# Processing Record 23 of Set 14 | basoda
# Processing Record 24 of Set 14 | dibaya
# City not found. Skipping...
# Processing Record 25 of Set 14 | oropesa
# Processing Record 26 of Set 14 | vila
# Processing Record 27 of Set 14 | devonport
# Processing Record 28 of Set 14 | pontes e lacerda
# Processing Record 29 of Set 14 | novo aripuana
# Processing Record 30 of Set 14 | ronneby
# Processing Record 31 of Set 14 | dali
# Processing Record 32 of Set 14 | mercedes
# Processing Record 33 of Set 14 | randolph
# Processing Record 34 of Set 14 | makung
# City not found. Skipping...
# Processing Record 35 of Set 14 | aras
# Processing Record 36 of Set 14 | burica
# City not found. Skipping...
# Processing Record 37 of Set 14 | sorland
# Processing Record 38 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 39 of Set 14 | kushmurun
# Processing Record 40 of Set 14 | cotacachi
# Processing Record 41 of Set 14 | thanh hoa
# Processing Record 42 of Set 14 | yaizu
# Processing Record 43 of Set 14 | beloha
# Processing Record 44 of Set 14 | taburao
# City not found. Skipping...
# Processing Record 45 of Set 14 | borba
# Processing Record 46 of Set 14 | coromandel
# Processing Record 47 of Set 14 | soyo
# Processing Record 48 of Set 14 | sept-iles
# Processing Record 49 of Set 14 | batagay-alyta
# Processing Record 50 of Set 14 | mae sai
# Processing Record 1 of Set 15 | west wendover
# Processing Record 2 of Set 15 | lubao
# Processing Record 3 of Set 15 | sibu
# Processing Record 4 of Set 15 | kogon
# Processing Record 5 of Set 15 | kalianget
# Processing Record 6 of Set 15 | asau
# Processing Record 7 of Set 15 | manggar
# Processing Record 8 of Set 15 | lanzhou
# Processing Record 9 of Set 15 | newport
# Processing Record 10 of Set 15 | russell
# Processing Record 11 of Set 15 | capinopolis
# Processing Record 12 of Set 15 | mapastepec
# Processing Record 13 of Set 15 | dombarovskiy
# Processing Record 14 of Set 15 | batemans bay
# Processing Record 15 of Set 15 | laurel
# Processing Record 16 of Set 15 | moses lake
# Processing Record 17 of Set 15 | sloboda
# Processing Record 18 of Set 15 | borama
# City not found. Skipping...
# Processing Record 19 of Set 15 | totkomlos
# Processing Record 20 of Set 15 | ternate
# Processing Record 21 of Set 15 | solovetskiy
# City not found. Skipping...
# Processing Record 22 of Set 15 | jieshi
# Processing Record 23 of Set 15 | alenquer
# Processing Record 24 of Set 15 | mundo nuevo
# Processing Record 25 of Set 15 | kaliganj
# Processing Record 26 of Set 15 | sinegorye
# Processing Record 27 of Set 15 | trat
# Processing Record 28 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 29 of Set 15 | pingliang
# Processing Record 30 of Set 15 | itarema
# Processing Record 31 of Set 15 | jacareacanga
# Processing Record 32 of Set 15 | hella
# Processing Record 33 of Set 15 | ferme-neuve
# Processing Record 34 of Set 15 | magole
# Processing Record 35 of Set 15 | chodavaram
# Processing Record 36 of Set 15 | basoko
# Processing Record 37 of Set 15 | immenstadt
# Processing Record 38 of Set 15 | leh
# Processing Record 39 of Set 15 | talakan
# Processing Record 40 of Set 15 | kieta
# Processing Record 41 of Set 15 | togur
# Processing Record 42 of Set 15 | bow island
# Processing Record 43 of Set 15 | binzhou
# Processing Record 44 of Set 15 | prizren
# Processing Record 45 of Set 15 | dauriya
# Processing Record 46 of Set 15 | marawi
# Processing Record 47 of Set 15 | virginia beach
# Processing Record 48 of Set 15 | henties bay
# Processing Record 49 of Set 15 | tilichiki
# Processing Record 50 of Set 15 | klishkivtsi
# Processing Record 1 of Set 16 | yar-sale
# Processing Record 2 of Set 16 | tooele
# Processing Record 3 of Set 16 | kaeo
# Processing Record 4 of Set 16 | imbituba
# Processing Record 5 of Set 16 | kondratovo
# Processing Record 6 of Set 16 | margate
# Processing Record 7 of Set 16 | ventspils
# Processing Record 8 of Set 16 | vasto
# Processing Record 9 of Set 16 | ulvila
# Processing Record 10 of Set 16 | kyra
# Processing Record 11 of Set 16 | shuiji
# Processing Record 12 of Set 16 | sal rei
# Processing Record 13 of Set 16 | shar
# Processing Record 14 of Set 16 | armacao dos buzios
# City not found. Skipping...
# Processing Record 15 of Set 16 | sohag
# Processing Record 16 of Set 16 | tigzirt
# Processing Record 17 of Set 16 | mangan
# Processing Record 18 of Set 16 | batagay
# Processing Record 19 of Set 16 | bowmore
# Processing Record 20 of Set 16 | tailai
# Processing Record 21 of Set 16 | daxian
# City not found. Skipping...
# Processing Record 22 of Set 16 | namwala
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 708

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df = city_data_df.rename(columns={"Weather":"Current Description"})

# %%
city_data_df.head()
# Out:
#       City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Vaini -21.2000 -175.2000     80.76        74          40        6.91
# 1    Tabou   4.4230   -7.3528     79.45        87          98        8.01
# 2     Luau -10.7073   22.2247     65.37        93         100        3.13
# 3  Turangi -39.0000  175.9333     59.07        43           1        2.15
# 4  Ushuaia -54.8000  -68.3000     53.26        47          40        4.61
#
#   Country                 Date Current Description
# 0      TO  2023-03-06 20:37:49    scattered clouds
# 1      CI  2023-03-06 20:39:15       moderate rain
# 2      AO  2023-03-06 20:39:16     overcast clouds
# 3      NZ  2023-03-06 20:39:17           clear sky
# 4      AR  2023-03-06 20:37:06          light rain

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df=city_data_df[column_order]

# Display sample data
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Vaini      TO -21.2000 -175.2000     80.76        74          40
# 1        Tabou      CI   4.4230   -7.3528     79.45        87          98
# 2         Luau      AO -10.7073   22.2247     65.37        93         100
# 3      Turangi      NZ -39.0000  175.9333     59.07        43           1
# 4      Ushuaia      AR -54.8000  -68.3000     53.26        47          40
# 5  Tuktoyaktuk      CA  69.4541 -133.0374    -22.00        76          40
# 6  Yellowknife      CA  62.4560 -114.3525     -8.45        70          75
# 7    Upernavik      GL  72.7868  -56.1549     15.30        87          25
# 8       Bethel      US  41.3712  -73.4140     50.94        29         100
# 9    Belomorsk      RU  64.5232   34.7668      0.55        99          99
#
#    Wind Speed Current Description
# 0        6.91    scattered clouds
# 1        8.01       moderate rain
# 2        3.13     overcast clouds
# 3        2.15           clear sky
# 4        4.61          light rain
# 5        8.05    scattered clouds
# 6       11.50       broken clouds
# 7        6.98    scattered clouds
# 8       13.80     overcast clouds
# 9        2.95     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_file ="Weather.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_file, index_label="City_ID")
